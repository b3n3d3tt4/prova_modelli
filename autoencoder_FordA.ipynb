# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import encoder_classifier as ec
importlib.reload(ec)
# Out:
# <module 'encoder_classifier' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\encoder_classifier.py'>

# %%
# -------------       
# DATASET PATHS
# -------------
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv"

# -------------------------
# TRAINING DATA PREPARATION
# -------------------------
train_dataset, train_loader, waves_train, labels_train = ec.dataload(train_path)


# ---------------------
# TEST DATA PREPARATION
# ---------------------
test_dataset, test_loader, waves_test, labels_test = ec.dataload(test_path)


# ---------------------------
# TEST PLOT TO VISUALISE DATA
# ---------------------------
ec.plot_wave(waves_train)
ec.plot_wave(waves_test)
# Out:
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv...
# Data loaded successfully. Waves shape: torch.Size([3601, 1, 500]), Labels shape: torch.Size([3601])
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv...
# Data loaded successfully. Waves shape: torch.Size([1320, 1, 500]), Labels shape: torch.Size([1320])
# This function plots the wave from the provided torch tensor.
# This function plots the wave from the provided torch tensor.

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

FordA_model = ec.AutoEncoder()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
FordA_model.train() 

trained_FordA = ec.train_autoencoder(FordA_model, train_loader, epochs=50)
# Out:
# Epoch [1/50] - Average loss: 0.9847
# Epoch [2/50] - Average loss: 0.9380
# Epoch [3/50] - Average loss: 0.9224
# Epoch [4/50] - Average loss: 0.9068
# Epoch [5/50] - Average loss: 0.8976
# Epoch [6/50] - Average loss: 0.8925
# Epoch [7/50] - Average loss: 0.8783
# Epoch [8/50] - Average loss: 0.8677
# Epoch [9/50] - Average loss: 0.8333
# Epoch [10/50] - Average loss: 0.7838
# Epoch [11/50] - Average loss: 0.7530
# Epoch [12/50] - Average loss: 0.7346
# Epoch [13/50] - Average loss: 0.7100
# Epoch [14/50] - Average loss: 0.6984
# Epoch [15/50] - Average loss: 0.6690
# Epoch [16/50] - Average loss: 0.6792
# Epoch [17/50] - Average loss: 0.6623
# Epoch [18/50] - Average loss: 0.6566
# Epoch [19/50] - Average loss: 0.6480
# Epoch [20/50] - Average loss: 0.6428
# Epoch [21/50] - Average loss: 0.6335
# Epoch [22/50] - Average loss: 0.6248
# Epoch [23/50] - Average loss: 0.6152
# Epoch [24/50] - Average loss: 0.6187
# Epoch [25/50] - Average loss: 0.6133
# Epoch [26/50] - Average loss: 0.6026
# Epoch [27/50] - Average loss: 0.6072
# Epoch [28/50] - Average loss: 0.6025
# Epoch [29/50] - Average loss: 0.6008
# Epoch [30/50] - Average loss: 0.5987
# Epoch [31/50] - Average loss: 0.5884
# Epoch [32/50] - Average loss: 0.5891
# Epoch [33/50] - Average loss: 0.5909
# Epoch [34/50] - Average loss: 0.5825
# Epoch [35/50] - Average loss: 0.5769
# Epoch [36/50] - Average loss: 0.5940
# Epoch [37/50] - Average loss: 0.5921
# Epoch [38/50] - Average loss: 0.5828
# Epoch [39/50] - Average loss: 0.5793
# Epoch [40/50] - Average loss: 0.5818
# Epoch [41/50] - Average loss: 0.5805
# Epoch [42/50] - Average loss: 0.5791
# Epoch [43/50] - Average loss: 0.5764
# Epoch [44/50] - Average loss: 0.5687
# Epoch [45/50] - Average loss: 0.5772
# Epoch [46/50] - Average loss: 0.5698
# Epoch [47/50] - Average loss: 0.5732
# Epoch [48/50] - Average loss: 0.5641
# Epoch [49/50] - Average loss: 0.5784
# Epoch [50/50] - Average loss: 0.5737

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_FordA = ec.test_autoencoder(trained_FordA, test_loader)
# Out:
# Test result: Average loss: 0.3485
