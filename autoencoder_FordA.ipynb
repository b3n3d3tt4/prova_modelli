# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import encoder_classifier as ec
importlib.reload(ec)
# Out:
# <module 'encoder_classifier' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\encoder_classifier.py'>

# %%
# -------------       
# DATASET PATHS
# -------------
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv"

# -------------------------
# TRAINING DATA PREPARATION
# -------------------------
train_dataset, train_loader, waves_train, labels_train = ec.dataload(train_path)


# ---------------------
# TEST DATA PREPARATION
# ---------------------
test_dataset, test_loader, waves_test, labels_test = ec.dataload(test_path)


# ---------------------------
# TEST PLOT TO VISUALISE DATA
# ---------------------------
ec.plot_wave(waves_train)
ec.plot_wave(waves_test)
# Out:
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv...
# Data loaded successfully. Waves shape: torch.Size([3601, 1, 500]), Labels shape: torch.Size([3601])
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv...
# Data loaded successfully. Waves shape: torch.Size([1320, 1, 500]), Labels shape: torch.Size([1320])
# This function plots the wave from the provided torch tensor.
# This function plots the wave from the provided torch tensor.

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

FordA_model = ec.AutoEncoder()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
FordA_model.train() 

trained_FordA = ec.train_autoencoder(FordA_model, train_loader, epochs=500)
# Out:
# Epoch [1/50] - Average loss: 0.9683
# Epoch [2/50] - Average loss: 0.9260
# Epoch [3/50] - Average loss: 0.9098
# Epoch [4/50] - Average loss: 0.8949
# Epoch [5/50] - Average loss: 0.8928
# Epoch [6/50] - Average loss: 0.8866
# Epoch [7/50] - Average loss: 0.8776
# Epoch [8/50] - Average loss: 0.8617
# Epoch [9/50] - Average loss: 0.8177
# Epoch [10/50] - Average loss: 0.7751
# Epoch [11/50] - Average loss: 0.7494
# Epoch [12/50] - Average loss: 0.7340
# Epoch [13/50] - Average loss: 0.7105
# Epoch [14/50] - Average loss: 0.6984
# Epoch [15/50] - Average loss: 0.6756
# Epoch [16/50] - Average loss: 0.6658
# Epoch [17/50] - Average loss: 0.6523
# Epoch [18/50] - Average loss: 0.6429
# Epoch [19/50] - Average loss: 0.6461
# Epoch [20/50] - Average loss: 0.6337
# Epoch [21/50] - Average loss: 0.6328
# Epoch [22/50] - Average loss: 0.6320
# Epoch [23/50] - Average loss: 0.6311
# Epoch [24/50] - Average loss: 0.6271
# Epoch [25/50] - Average loss: 0.6177
# Epoch [26/50] - Average loss: 0.6059
# Epoch [27/50] - Average loss: 0.6133
# Epoch [28/50] - Average loss: 0.5955
# Epoch [29/50] - Average loss: 0.6056
# Epoch [30/50] - Average loss: 0.5917
# Epoch [31/50] - Average loss: 0.5936
# Epoch [32/50] - Average loss: 0.5900
# Epoch [33/50] - Average loss: 0.5982
# Epoch [34/50] - Average loss: 0.5851
# Epoch [35/50] - Average loss: 0.5968
# Epoch [36/50] - Average loss: 0.5786
# Epoch [37/50] - Average loss: 0.5884
# Epoch [38/50] - Average loss: 0.5945
# Epoch [39/50] - Average loss: 0.5788
# Epoch [40/50] - Average loss: 0.5791
# Epoch [41/50] - Average loss: 0.5795
# Epoch [42/50] - Average loss: 0.5836
# Epoch [43/50] - Average loss: 0.5811
# Epoch [44/50] - Average loss: 0.5816
# Epoch [45/50] - Average loss: 0.5719
# Epoch [46/50] - Average loss: 0.5673
# Epoch [47/50] - Average loss: 0.5694
# Epoch [48/50] - Average loss: 0.5689
# Epoch [49/50] - Average loss: 0.5847
# Epoch [50/50] - Average loss: 0.5786

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_FordA = ec.test_autoencoder(trained_FordA, test_loader)
# Out:
# Test result: Average loss: 0.3906
