# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import encoder_classifier as ec
importlib.reload(ec)
# Out:
# <module 'encoder_classifier' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\encoder_classifier.py'>

# %%
# -------------       
# DATASET PATHS
# -------------
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv"

# -------------------------
# TRAINING DATA PREPARATION
# -------------------------
train_dataset, train_loader, waves_train, labels_train = ec.dataload(train_path)


# ---------------------
# TEST DATA PREPARATION
# ---------------------
test_dataset, test_loader, waves_test, labels_test = ec.dataload(test_path)


# ---------------------------
# TEST PLOT TO VISUALISE DATA
# ---------------------------
ec.plot_wave(waves_train)
ec.plot_wave(waves_test)
# Out:
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv...
# Data loaded successfully. Waves shape: torch.Size([3601, 1, 500]), Labels shape: torch.Size([3601])
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv...
# Data loaded successfully. Waves shape: torch.Size([1320, 1, 500]), Labels shape: torch.Size([1320])
# This function plots the wave from the provided torch tensor.
# This function plots the wave from the provided torch tensor.

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

FordA_model = ec.AutoEncoder()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
FordA_model.train() 

trained_FordA = ec.train_autoencoder(FordA_model, train_loader, epochs=200)
# Out:
# Epoch [1/200] - Average loss: 0.4106
# Epoch [2/200] - Average loss: 0.0929
# Epoch [3/200] - Average loss: 0.0450
# Epoch [4/200] - Average loss: 0.0252
# Epoch [5/200] - Average loss: 0.0180
# Epoch [6/200] - Average loss: 0.0130
# Epoch [7/200] - Average loss: 0.0112
# Epoch [8/200] - Average loss: 0.0093
# Epoch [9/200] - Average loss: 0.0085
# Epoch [10/200] - Average loss: 0.0077
# Epoch [11/200] - Average loss: 0.0064
# Epoch [12/200] - Average loss: 0.0069
# Epoch [13/200] - Average loss: 0.0057
# Epoch [14/200] - Average loss: 0.0063
# Epoch [15/200] - Average loss: 0.0053
# Epoch [16/200] - Average loss: 0.0048
# Epoch [17/200] - Average loss: 0.0055
# Epoch [18/200] - Average loss: 0.0047
# Epoch [19/200] - Average loss: 0.0049
# Epoch [20/200] - Average loss: 0.0046
# Epoch [21/200] - Average loss: 0.0040
# Epoch [22/200] - Average loss: 0.0043
# Epoch [23/200] - Average loss: 0.0042
# Epoch [24/200] - Average loss: 0.0042
# Epoch [25/200] - Average loss: 0.0040
# Epoch [26/200] - Average loss: 0.0042
# Epoch [27/200] - Average loss: 0.0035
# Epoch [28/200] - Average loss: 0.0036
# Epoch [29/200] - Average loss: 0.0037
# Epoch [30/200] - Average loss: 0.0038
# Epoch [31/200] - Average loss: 0.0038
# Epoch [32/200] - Average loss: 0.0037
# Epoch [33/200] - Average loss: 0.0041
# Epoch [34/200] - Average loss: 0.0038
# Epoch [35/200] - Average loss: 0.0034
# Epoch [36/200] - Average loss: 0.0030
# Epoch [37/200] - Average loss: 0.0028
# Epoch [38/200] - Average loss: 0.0028
# Epoch [39/200] - Average loss: 0.0032
# Epoch [40/200] - Average loss: 0.0033
# Epoch [41/200] - Average loss: 0.0028
# Epoch [42/200] - Average loss: 0.0024
# Epoch [43/200] - Average loss: 0.0025
# Epoch [44/200] - Average loss: 0.0030
# Epoch [45/200] - Average loss: 0.0028
# Epoch [46/200] - Average loss: 0.0029
# Epoch [47/200] - Average loss: 0.0032
# Epoch [48/200] - Average loss: 0.0034
# Epoch [49/200] - Average loss: 0.0025
# Epoch [50/200] - Average loss: 0.0023
# Epoch [51/200] - Average loss: 0.0026
# Epoch [52/200] - Average loss: 0.0029
# Epoch [53/200] - Average loss: 0.0020
# Epoch [54/200] - Average loss: 0.0022
# Epoch [55/200] - Average loss: 0.0024
# Epoch [56/200] - Average loss: 0.0025
# Epoch [57/200] - Average loss: 0.0025
# Epoch [58/200] - Average loss: 0.0024
# Epoch [59/200] - Average loss: 0.0021
# Epoch [60/200] - Average loss: 0.0028
# Epoch [61/200] - Average loss: 0.0033
# Epoch [62/200] - Average loss: 0.0030
# Epoch [63/200] - Average loss: 0.0019
# Epoch [64/200] - Average loss: 0.0020
# Epoch [65/200] - Average loss: 0.0020
# Epoch [66/200] - Average loss: 0.0025
# Epoch [67/200] - Average loss: 0.0022
# Epoch [68/200] - Average loss: 0.0022
# Epoch [69/200] - Average loss: 0.0032
# Epoch [70/200] - Average loss: 0.0025
# Epoch [71/200] - Average loss: 0.0018
# Epoch [72/200] - Average loss: 0.0015

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_FordA = ec.test_autoencoder(trained_FordA, test_loader)
# Out:
# Test result: Average loss: 0.1520
