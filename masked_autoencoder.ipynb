# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import encoder_classifier as ec
importlib.reload(ec)
# Out:
# <module 'encoder_classifier' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\encoder_classifier.py'>

# %%
# -------------       
# DATASET PATHS
# -------------
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv"

# -------------------------
# TRAINING DATA PREPARATION
# -------------------------
train_dataset, train_loader, waves_train, labels_train = ec.dataload_csv(train_path)


# ---------------------
# TEST DATA PREPARATION
# ---------------------
test_dataset, test_loader, waves_test, labels_test = ec.dataload_csv(test_path)


# ---------------------------
# TEST PLOT TO VISUALISE DATA
# ---------------------------
# ec.plot_wave(waves_train)
# ec.plot_wave(waves_test)
# Out:
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TRAIN_set.csv...
# Data loaded successfully. Waves shape: torch.Size([3601, 1, 500]), Labels shape: torch.Size([3601])
# This function loads the data from the specified path and returns (in this order):
#  - the dataset - the loader - the waves and labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\FordA\TEST_set.csv...
# Data loaded successfully. Waves shape: torch.Size([1320, 1, 500]), Labels shape: torch.Size([1320])

# %% [markdown]
# # 1. MASKED AUTOENCODER training + test

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

FordA_model = ec.AutoEncoder()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
FordA_model.train() 

trained_mae_FordA = ec.train_masked_autoencoder(FordA_model, train_loader, epochs=50)
# Out:
# Epoch [1/50] - Average loss: 0.5276
# Epoch [2/50] - Average loss: 0.3958
# Epoch [3/50] - Average loss: 0.3691
# Epoch [4/50] - Average loss: 0.3468
# Epoch [5/50] - Average loss: 0.3416
# Epoch [6/50] - Average loss: 0.3263
# Epoch [7/50] - Average loss: 0.3009
# Epoch [8/50] - Average loss: 0.2986
# Epoch [9/50] - Average loss: 0.2859
# Epoch [10/50] - Average loss: 0.2879
# Epoch [11/50] - Average loss: 0.2932
# Epoch [12/50] - Average loss: 0.2701
# Epoch [13/50] - Average loss: 0.2564
# Epoch [14/50] - Average loss: 0.2658
# Epoch [15/50] - Average loss: 0.2539
# Epoch [16/50] - Average loss: 0.2531
# Epoch [17/50] - Average loss: 0.2451
# Epoch [18/50] - Average loss: 0.2427
# Epoch [19/50] - Average loss: 0.2388
# Epoch [20/50] - Average loss: 0.2398
# Epoch [21/50] - Average loss: 0.2377
# Epoch [22/50] - Average loss: 0.2376
# Epoch [23/50] - Average loss: 0.2291
# Epoch [24/50] - Average loss: 0.2339
# Epoch [25/50] - Average loss: 0.2240
# Epoch [26/50] - Average loss: 0.2241
# Epoch [27/50] - Average loss: 0.2319
# Epoch [28/50] - Average loss: 0.2254
# Epoch [29/50] - Average loss: 0.2138
# Epoch [30/50] - Average loss: 0.2251
# Epoch [31/50] - Average loss: 0.2180
# Epoch [32/50] - Average loss: 0.2177
# Epoch [33/50] - Average loss: 0.2254
# Epoch [34/50] - Average loss: 0.2193
# Epoch [35/50] - Average loss: 0.2175
# Epoch [36/50] - Average loss: 0.2211
# Epoch [37/50] - Average loss: 0.2193
# Epoch [38/50] - Average loss: 0.2146
# Epoch [39/50] - Average loss: 0.2202
# Epoch [40/50] - Average loss: 0.2089
# Epoch [41/50] - Average loss: 0.2115
# Epoch [42/50] - Average loss: 0.2098
# Epoch [43/50] - Average loss: 0.2079
# Epoch [44/50] - Average loss: 0.2126
# Epoch [45/50] - Average loss: 0.2113
# Epoch [46/50] - Average loss: 0.2141
# Epoch [47/50] - Average loss: 0.2075
# Epoch [48/50] - Average loss: 0.2092
# Epoch [49/50] - Average loss: 0.2074
# Epoch [50/50] - Average loss: 0.2141

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_ae_FordA = ec.test_autoencoder(trained_mae_FordA, test_loader)
# Out:
# Recontruction - Test result: Average loss: 0.3080
