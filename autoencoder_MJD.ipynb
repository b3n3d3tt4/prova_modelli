# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib
import h5py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import encoder_classifier as ec
importlib.reload(ec)
# Out:
# <module 'encoder_classifier' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\encoder_classifier.py'>

# %% [markdown]
# # 0. DATA LOADING

# %%
npml_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_NPML_0.hdf5"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Test_0.hdf5"
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Train_0.hdf5"

train_dataset, train_loader, waves_train, labels_train = ec.dataload_h5py(train_path)
test_dataset, test_loader, waves_test, labels_test= ec.dataload_h5py(test_path)
# Out:
# This function loads the data from the specified HDF5 path and returns (in this order):
#  - the dataset
#  - the loader
#  - the waves
#  - the dummy labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Train_0.hdf5...
# Data loaded successfully. Waves shape: torch.Size([65000, 1, 3800]), Labels shape: torch.Size([65000])
# This function loads the data from the specified HDF5 path and returns (in this order):
#  - the dataset
#  - the loader
#  - the waves
#  - the dummy labels
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Test_0.hdf5...
# Data loaded successfully. Waves shape: torch.Size([65000, 1, 3800]), Labels shape: torch.Size([65000])

# %% [markdown]
# # 1. AUTOENCODER training + test

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

MJD_model = ec.AutoEncoder()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
MJD_model.train() 

trained_ae_MJD = ec.train_autoencoder(MJD_model, train_loader, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[12], line 11
#       7 # This comand put the model in training mode
#       8 # that means that some mathematichal structures are behaving in a specific mode
#       9 MJD_model.train()
# ---> 11 trained_ae_MJD = ec.train_autoencoder(MJD_model, train_loader, epochs=10)
#
# File c:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\encoder_classifier.py:362, in train_autoencoder(model, loader, epochs)
#     359 noisy_waves = white_noise(shifted_waves)
#     361 # Forward pass
# --> 362 latent, reconstructed = model(noisy_waves) # Automatically recalls the forward function
#     364 # Loss calculation
#     365 loss = autoencoder_loss(reconstructed, shifted_waves)
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\encoder_classifier.py:278, in AutoEncoder.forward(self, x)
#     276 def forward(self, x):
#     277     # Here we define the forward pass ion order to process the "x" data through the encoder and obtain the latent representation.
# --> 278     latent = self.encoder(x)
#     279     reconstructed = self.decoder(latent)
#     280     return latent, reconstructed
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\nn\modules\linear.py:134, in Linear.forward(self, input)
#     130 def forward(self, input: Tensor) -> Tensor:
#     131     """
#     132     Runs the forward pass.
#     133     """
# --> 134     return F.linear(input, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (32x30400 and 4000x128)

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_ae_MJD = ec.test_autoencoder(trained_ae_MJD, test_loader)
