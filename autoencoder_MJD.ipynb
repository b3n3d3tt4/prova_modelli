# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pandas as pd
import importlib
import h5py

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader

import ae_for_MJD as aeMJD
importlib.reload(aeMJD)
# Out:
# <module 'ae_for_MJD' from 'c:\\Users\\Utente\\Desktop\\uni\\MAGISTRALE\\___TESI_magistrale\\github\\prove_modelli\\ae_for_MJD.py'>

# %% [markdown]
# # 0. DATA LOADING

# %%
npml_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_NPML_0.hdf5"
test_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Test_0.hdf5"
train_path = r"C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Train_0.hdf5"

train_dataset, train_loader, waves_train= aeMJD.dataload_h5py(train_path)
test_dataset, test_loader, waves_test = aeMJD.dataload_h5py(test_path)
# Out:
# This function loads the data from the specified HDF5 path and returns (in this order):
#  - the dataset
#  - the loader
#  - the waves
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Train_0.hdf5...
# Data loaded successfully. Waves shape: torch.Size([65000, 1, 3800])
# This function loads the data from the specified HDF5 path and returns (in this order):
#  - the dataset
#  - the loader
#  - the waves
# Loading data from C:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\MJD_data\MJD_Test_0.hdf5...
# Data loaded successfully. Waves shape: torch.Size([65000, 1, 3800])

# %% [markdown]
# # 1. AUTOENCODER training + test

# %%
# ------------------------------------
# MODEL TRAINING for the FordA dataset
# ------------------------------------

MJD_model = aeMJD.AutoEncoderHDF5()

# This comand put the model in training mode 
# that means that some mathematichal structures are behaving in a specific mode
MJD_model.train() 

trained_ae_MJD = aeMJD.train_autoencoder(MJD_model, train_loader, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 11
#       7 # This comand put the model in training mode
#       8 # that means that some mathematichal structures are behaving in a specific mode
#       9 MJD_model.train()
# ---> 11 trained_ae_MJD = aeMJD.train_autoencoder(MJD_model, train_loader, epochs=10)
#
# File c:\Users\Utente\Desktop\uni\MAGISTRALE\___TESI_magistrale\github\prove_modelli\ae_for_MJD.py:278, in train_autoencoder(model, loader, epochs)
#     275 loss.backward()
#     277 # Weights upgrade
# --> 278 optimizer.step()
#     280 # Epoch loss calculation
#     281 epoch_loss += loss.item()
#
# File c:\Users\Utente\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\optim\optimizer.py:535, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     530             raise RuntimeError(
# ...

# %%
# -----------------------
# TEST of the FordA_model
# -----------------------

tested_ae_MJD = aeMJD.test_autoencoder(trained_ae_MJD, test_loader)
